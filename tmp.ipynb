# %%
from Rosmaster_Lib import Rosmaster
from utils import *

bot = Rosmaster()
bot.clear_auto_report_data()
bot.create_receive_threading()
# Out:
# Rosmaster Serial Opened! Baudrate=115200
# ----------------create receive threading--------------

# %%
del bot
# Out:
# Exception in thread task_serial_receive:
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/Rosmaster_Lib-3.3.9-py3.11.egg/Rosmaster_Lib/Rosmaster_Lib.py", line 260, in __receive_data
#   File "/usr/lib/python3/dist-packages/serial/serialposix.py", line 595, in read
#     raise SerialException(
# serial.serialutil.SerialException: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# serial Close!

# %%
print(f"Voltage remain: {bot.get_battery_voltage()}")
_, _, init_yaw = bot.get_imu_attitude_data()
# init_yaw = map_imu_angle(init_yaw)
print('Initial Yaw:', init_yaw)
# Out:
# Voltage remain: 10.5
# Initial Yaw: 91.48417112765

# %%
init_arm(bot)

# %%
bot.set_car_motion(0, 0, 0)

# %%
_, _, init_yaw = bot.get_imu_attitude_data()
# Rotate RIGHT
rotate_robot(bot, -90, spd=0.2, delay=1)
# Out:
# [INFO] Rotating from yaw 91.26 to target yaw 1.26 degrees
# [INFO] Rotation completed.
# Current yaw: 1.49 degrees | Target yaw: 1.26 degrees
# Exception in thread task_serial_receive:
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/Rosmaster_Lib-3.3.9-py3.11.egg/Rosmaster_Lib/Rosmaster_Lib.py", line 260, in __receive_data
#   File "/usr/lib/python3/dist-packages/serial/serialposix.py", line 595, in read
#     raise SerialException(
# serial.serialutil.SerialException: device reports readiness to read but returned no data (device disconnected or multiple access on port?)

# %%
_, _, init_yaw = bot.get_imu_attitude_data()
run_straight_robot(bot, target_yaw=init_yaw, base_speed=37, target_distance=0.5)
# Out:
# [INFO] Motor PID set to Kp=1.2, Ki=0.1, Kd=0.1
# [INFO] Initial ticks: [125763, 126034, -91863, -90581]
# [INFO] Moving 0.50 m at base speed 37
# [INFO] Stopped at 0.510 m.

# %%
_, _, init_yaw = bot.get_imu_attitude_data()
# Rotate LEFT
rotate_robot(bot, 110, spd=0.2, delay=1)
# Out:
# [INFO] Rotating from yaw -96.84 to target yaw 13.16 degrees
# [INFO] Rotation completed.
# Current yaw: 12.77 degrees | Target yaw: 13.16 degrees
